# %%
import pandas as pd

# %%
Subagan=pd.read_csv('C://Users//Personal//Documents//Subagan20xx-2023.csv')
Subagan.drop('Hora Entrada', axis=1, inplace=True)
Subagan['Precio Final']=Subagan['Precio Final'].astype(str)
Subagan=Subagan.loc[Subagan['Precio Final'].str.isnumeric()]

Suganar=pd.read_csv('C://Users//Personal//Documents//Suganar202x.csv')
Suganar.drop('Hora Entrada', axis=1, inplace=True)
Subagan
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_10536\2677570106.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   Subagan=pd.read_csv('C://Users//Personal//Documents//Subagan20xx-2023.csv')
#         Unnamed: 0  Lote Sexo  Cantidad  Peso Total  Peso Promedio  \
# 0            22618     1   ML         2     216.000            108
# 1            22619     2   VE         1     362.000            362
# 2            22620     3   VE         2     732.000            366
# 3            22621     4   VE         2     762.000            381
# 4            22622     5   HV         1     468.000            468
# ...            ...   ...  ...       ...         ...            ...
# 203216      244025    17   HL         1     232.000            232
# 203217      244026    18   HL         1     158.000            158
# 203218      244027    19   HL         9       1.182            131
# ...

# %%
Subaganar=pd.concat([Subagan, Suganar], ignore_index=True)
Subaganar



Subaganar.dropna(inplace=True, subset=['Precio Final', 'Precio Base'])
Subaganar['Precio Final']=Subaganar['Precio Final'].astype(str)
Subaganar=Subaganar.loc[Subaganar['Precio Final'].str.isnumeric()]
Subaganar['Precio Final']=Subaganar['Precio Final'].astype(int)
miss= ((Subaganar['Precio Final']>0)&(Subaganar['Precio Final']<20000))
Subaganar=Subaganar.loc[miss]





Subaganar.Sexo.replace('VH','HV', inplace=True)

Subaganar.to_csv('C://Users//Personal//Documents//Subaganar202x.csv')
Subaganar
# Out:
#         Unnamed: 0 Lote Sexo Cantidad Peso Total Peso Promedio   Procedencia  \
# 0            22618    1   ML        2      216.0           108    LAS PULGAS
# 1            22619    2   VE        1      362.0           362    LAS PULGAS
# 2            22620    3   VE        2      732.0           366    LAS PULGAS
# 3            22621    4   VE        2      762.0           381    LAS PULGAS
# 4            22622    5   HV        1      468.0           468    LAS PULGAS
# ...            ...  ...  ...      ...        ...           ...           ...
# 269714       68223  041   HV        1        280           280  AGUAS CLARAS
# 269715       68224  042   HV        1        444           444  AGUAS CLARAS
# 269716       68225  043   MC        1        362           362  AGUAS CLARAS
# 269717       68226  044   MC        1        344           344  AGUAS CLARAS
# 269718       68227  045   ML        5       1288           258  AGUAS CLARAS
#
# ...
